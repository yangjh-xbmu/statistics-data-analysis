# %%
print('hi')
# Out:
# hi

# %%
# My First Python Program
# 我想在这个脚本中写一些代码，来实现python变量的定义和使用。下面是一个简单的示例，展示了如何定义变量并进行基本的运算。

# 定义变量
x = 10
y = 5.3
print("x =", x)
print("y =", y)

# 变量的类型：数值类
print("Type of x:", type(x))
print("Type of y:", type(y))

# 变量的类型：字符串类
name = "小明"
print("name =", name)
print("Type of name:", type(name))

# 变量的类型：布尔类
is_student = True
print("is_student =", is_student)
print("Type of is_student:", type(is_student))

# 变量的类型：列表类
fruits = ["apple", "banana", "cherry"]
print("fruits =", fruits)
print("Type of fruits:", type(fruits))

# 变量的类型：字典类
person = {"name": "小明", "age": 20}
print("person =", person)
print("Type of person:", type(person))

# 变量的类型：元组类
coordinates = (10.0, 20.0)  
print("coordinates =", coordinates)
print("Type of coordinates:", type(coordinates))

# 变量的类型：集合类
unique_numbers = {1, 2, 3, 4, 5} 
print("unique_numbers =", unique_numbers)
print("Type of unique_numbers:", type(unique_numbers))

# 变量的类型：NoneType
nothing = None 
print("nothing =", nothing)
print("Type of nothing:", type(nothing))
# Out:
# x = 10
# y = 5.3
# Type of x: <class 'int'>
# Type of y: <class 'float'>
# name = 小明
# Type of name: <class 'str'>
# is_student = True
# Type of is_student: <class 'bool'>
# fruits = ['apple', 'banana', 'cherry']
# Type of fruits: <class 'list'>
# person = {'name': '小明', 'age': 20}
# Type of person: <class 'dict'>
# coordinates = (10.0, 20.0)
# Type of coordinates: <class 'tuple'>
# unique_numbers = {1, 2, 3, 4, 5}
# Type of unique_numbers: <class 'set'>
# nothing = None
# Type of nothing: <class 'NoneType'>

# %%
# 数值变量的运算
print("x + y =", x + y)
print("x - y =", x - y)
print("x * y =", x * y)
print("x / y =", x / y)
print("x // y =", x // y)
print("x % y =", x % y)
print("x ** y =", x ** y)

# 字符串变量的运算
greeting = "Hello"
print("greeting =", greeting)
print("greeting + ' World' =", greeting + " World")
print("greeting * 3 =", greeting * 3)

# 布尔变量的运算
print("is_student and False =", is_student and False)
print("is_student or False =", is_student or False)
print("not is_student =", not is_student)

# 列表变量的运算
print("fruits[0] =", fruits[0]) 
print("fruits[1] =", fruits[1])
print("fruits[2] =", fruits[2])
print("len(fruits) =", len(fruits))
# Out:
# x + y = 15.3
# x - y = 4.7
# x * y = 53.0
# x / y = 1.8867924528301887
# x // y = 1.0
# x % y = 4.7
# x ** y = 199526.2314968879
# greeting = Hello
# greeting + ' World' = Hello World
# greeting * 3 = HelloHelloHello
# is_student and False = False
# is_student or False = True
# not is_student = False
